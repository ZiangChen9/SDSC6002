# %% [markdown]
# # 0.Install

# %%
# !pip install torch gpytorch botorch

# %% [markdown]
# # 1.Import

# %%
import torch
import gpytorch
import botorch
import matplotlib.pyplot as plt
from botorch.test_functions.synthetic import Ackley,ThreeHumpCamel,Hartmann
from numpy.ma.core import negative
from torch.quasirandom import SobolEngine
from botorch.sampling.normal import SobolQMCNormalSampler

from botorch.models import SingleTaskGP
from botorch.acquisition import qKnowledgeGradient, qLogNoisyExpectedImprovement
from botorch.acquisition.predictive_entropy_search import qPredictiveEntropySearch
from gpytorch.mlls import ExactMarginalLogLikelihood
from botorch.fit import fit_gpytorch_mll
from tqdm.notebook import tqdm
from botorch.models.transforms import Normalize, Standardize
from botorch.optim import optimize_acqf

from gpytorch.means import LinearMean
from gpytorch.kernels import ScaleKernel, RBFKernel
import warnings
import csv

# %% [markdown]
# # 2.Test Function: Many Local Minima: Ackley

# %%
tkwargs = {
    "dtype": torch.float64,
    "device": torch.device("cuda:1"),
}
d=2
bounds=torch.tensor([[-32.7680, -32.7680],[32.7680,  32.7680]],**tkwargs)
optimizer =torch.tensor([0.0, 0.0])
optimal_value=0.0
optimal_value=-optimal_value
test_f= Ackley(negate = True)
noise =0.5
def f1(x,noise):
  y=test_f(x)
  y=test_f(x)+noise*torch.randn_like(y)
  return y.unsqueeze(-1)
# bounds=test_f.bounds
def f(x,noise):
  return f1(x,noise)

# %% [markdown]
# # 3.BayesOpt Loop:  Ackley+qKG+ConstantMean+Matern(3/2)

# %%
best_values=[]
result_reals=[]
runs=30
for i in tqdm(range(runs)):
  # Set SEED
  SEED=i
  torch.manual_seed(SEED)
  torch.cuda.manual_seed_all(SEED)
  d=2

  # Initial xt and yt
  Init_num=10*d
  sobol= SobolEngine(dimension=d, scramble=True)
  xt = sobol.draw(Init_num).to(dtype=torch.float64,device=torch.device("cuda:1"))
  xt[:,0]=xt[:,0]*(bounds[1][0]-bounds[0][0])+bounds[0][0]
  xt[:,1]=xt[:,1]*(bounds[1][1]-bounds[0][1])+bounds[0][1]
  yt=f(xt,noise)
  yr=f(xt,0)

  # Records
  result_real=[val.item() for val in yr]
  result_noise=[val.item() for val in yt]
  best_value=[-max(result_real)]

  # Budget
  budget=40*d

  # Sampler
  sampler = SobolQMCNormalSampler(torch.Size([1024]))

  # Mean & Kernel
  mean_fn = gpytorch.means.ConstantMean()
  kernel_fn = gpytorch.kernels.ScaleKernel(gpytorch.kernels.MaternKernel(nu=1.5))

  # Loop
  for j in tqdm(range(budget)):
    # GP Model
    gp_1=SingleTaskGP(train_X=xt,
                      train_Y=yt,
                      input_transform=Normalize(d=d),
                      outcome_transform=Standardize(m=1),
                      mean_module=mean_fn,
                      covar_module=kernel_fn)
    # Fit
    fit_gpytorch_mll(ExactMarginalLogLikelihood(gp_1.likelihood, gp_1))

    # Acquisition Function
    acf=qKnowledgeGradient(model=gp_1,num_fantasies=128)

    # next train_X
    with warnings.catch_warnings():
      warnings.filterwarnings('ignore', category=RuntimeWarning)
      candidate, acq_value = optimize_acqf(acf, bounds=bounds, q=1, num_restarts=20, raw_samples=50,options={"dtype": torch.float64})

    # List of train_X
    xt= torch.cat([xt, candidate], dim=0)

    # next train_Y & next real_Y
    yr_next = f(candidate,0)
    yt_next = f(candidate,noise)

    # List of train_Y
    yt = torch.cat([yt, yt_next])

    # List of train_Y & List of real_Y
    result_noise.append(yt_next.squeeze(-1).item())
    result_real.append(yr_next.squeeze(-1).item())
    best_value.append(-max(result_real))

  # Update Records
  result_reals.append(result_real)
  best_values.append(best_value)

  # Plot
  iter_num=[k for k in range(0, budget+1)]
  min=[optimal_value for k in range(0, budget+1)]
  if i%3 == 0:
    plt.figure(figsize=(8, 6))
    plt.xlabel("Number of evaluations")
    plt.ylabel("Best value found")
    plt.title(f"Runs:{i+1}-{i+1+2}")
    plt.plot(iter_num,min,'--',label='Optimal Value')
  plt.plot(iter_num,best_value,label=f'Run:{i+1}')
  plt.legend(loc='upper right',)

  # Print
#   print(result_real)
# print(result_reals)
with open('result_reals_Ackley+qKG+ConstantMean+Matern(1.5).csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(best_values)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/80 [00:00<?, ?it/s]
#   0%|          | 0/80 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 53
#      51 with warnings.catch_warnings():
#      52   warnings.filterwarnings('ignore', category=RuntimeWarning)
# ---> 53   candidate, acq_value = optimize_acqf(acf, bounds=bounds, q=1, num_restarts=20, raw_samples=50,options={"dtype": torch.float64})
#      55 # List of train_X
#      56 xt= torch.cat([xt, candidate], dim=0)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/optim/optimize.py:631, in optimize_acqf(acq_function, bounds, q, num_restarts, raw_samples, options, inequality_constraints, equality_constraints, nonlinear_inequality_constraints, fixed_features, post_processing_func, batch_initial_conditions, return_best_only, gen_candidates, sequential, ic_generator, timeout_sec, return_full_tree, retry_on_optimization_warning, **ic_gen_kwargs)
#     608     gen_candidates = gen_candidates_scipy
#     609 opt_acqf_inputs = OptimizeAcqfInputs(
#     610     acq_function=acq_function,
#     611     bounds=bounds,
#    (...)    629     ic_gen_kwargs=ic_gen_kwargs,
#     630 )
# --> 631 return _optimize_acqf(opt_inputs=opt_acqf_inputs)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/optim/optimize.py:652, in _optimize_acqf(opt_inputs)
#     649     return _optimize_acqf_sequential_q(opt_inputs=opt_inputs)
#     651 # Batch optimization (including the case q=1)
# --> 652 return _optimize_acqf_batch(opt_inputs=opt_inputs)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/optim/optimize.py:408, in _optimize_acqf_batch(opt_inputs)
#     405         batch_acq_values = torch.cat(batch_acq_values_list).flatten()
#     406     return batch_candidates, batch_acq_values, opt_warnings
# --> 408 batch_candidates, batch_acq_values, ws = _optimize_batch_candidates()
#     410 optimization_warning_raised = any(
#     411     issubclass(w.category, OptimizationWarning) for w in ws
#     412 )
#     413 if optimization_warning_raised and opt_inputs.retry_on_optimization_warning:
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/optim/optimize.py:385, in _optimize_acqf_batch.<locals>._optimize_batch_candidates()
#     380 with warnings.catch_warnings(record=True) as ws:
#     381     warnings.simplefilter("always", category=OptimizationWarning)
#     382     (
#     383         batch_candidates_curr,
#     384         batch_acq_values_curr,
# --> 385     ) = opt_inputs.gen_candidates(
#     386         batched_ics_,
#     387         opt_inputs.acq_function,
#     388         lower_bounds=lower_bounds,
#     389         upper_bounds=upper_bounds,
#     390         options=gen_options,
#     391         fixed_features=opt_inputs.fixed_features,
#     392         timeout_sec=timeout_sec,
#     393         **gen_kwargs,
#     394     )
#     395 opt_warnings += ws
#     396 batch_candidates_list.append(batch_candidates_curr)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/generation/gen.py:240, in gen_candidates_scipy(initial_conditions, acquisition_function, lower_bounds, upper_bounds, inequality_constraints, equality_constraints, nonlinear_inequality_constraints, options, fixed_features, timeout_sec)
#     237 def f(x):
#     238     return -acquisition_function(x)
# --> 240 res = minimize_with_timeout(
#     241     fun=f_np_wrapper,
#     242     args=(f,),
#     243     x0=x0,
#     244     method=options.get("method", "SLSQP" if constraints else "L-BFGS-B"),
#     245     jac=with_grad,
#     246     bounds=bounds,
#     247     constraints=constraints,
#     248     callback=options.get("callback", None),
#     249     options={
#     250         k: v
#     251         for k, v in options.items()
#     252         if k not in ["method", "callback", "with_grad"]
#     253     },
#     254     timeout_sec=timeout_sec,
#     255 )
#     256 _process_scipy_result(res=res, options=options)
#     258 candidates = fix_features(
#     259     X=torch.from_numpy(res.x).to(initial_conditions).reshape(shapeX),
#     260     fixed_features=fixed_features,
#     261 )
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/optim/utils/timeout.py:86, in minimize_with_timeout(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options, timeout_sec)
#      83     # To prevent slowdowns after scipy 1.15.
#      84     # See https://github.com/scipy/scipy/issues/22438.
#      85     with threadpool_limits(limits=1, user_api="blas"):
# ---> 86         return optimize.minimize(
#      87             fun=fun,
#      88             x0=x0,
#      89             args=args,
#      90             method=method,
#      91             jac=jac,
#      92             hess=hess,
#      93             hessp=hessp,
#      94             bounds=bounds,
#      95             constraints=constraints,
#      96             tol=tol,
#      97             callback=wrapped_callback,
#      98             options=options,
#      99         )
#     100 except OptimizationTimeoutError as e:
#     101     msg = f"Optimization timed out after {e.runtime} seconds."
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/scipy/optimize/_minimize.py:738, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     735     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     736                              **options)
#     737 elif meth == 'l-bfgs-b':
# --> 738     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     739                            callback=callback, **options)
#     740 elif meth == 'tnc':
#     741     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     742                         **options)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/scipy/optimize/_lbfgsb_py.py:441, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     433 _lbfgsb.setulb(m, x, low_bnd, upper_bnd, nbd, f, g, factr, pgtol, wa,
#     434                iwa, task, lsave, isave, dsave, maxls, ln_task)
#     436 if task[0] == 3:
#     437     # The minimization routine wants f and g at the current x.
#     438     # Note that interruptions due to maxfun are postponed
#     439     # until the completion of the current minimization iteration.
#     440     # Overwrite f and g:
# --> 441     f, g = func_and_grad(x)
#     442 elif task[0] == 1:
#     443     # new iteration
#     444     n_iterations += 1
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:344, in ScalarFunction.fun_and_grad(self, x)
#     342 if not np.array_equal(x, self.x):
#     343     self._update_x(x)
# --> 344 self._update_fun()
#     345 self._update_grad()
#     346 return self.f, self.g
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:295, in ScalarFunction._update_fun(self)
#     293 def _update_fun(self):
#     294     if not self.f_updated:
# --> 295         fx = self._wrapped_fun(self.x)
#     296         if fx < self._lowest_f:
#     297             self._lowest_x = self.x
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:21, in _wrapper_fun.<locals>.wrapped(x)
#      17 ncalls[0] += 1
#      18 # Send a copy because the user may overwrite it.
#      19 # Overwriting results in undefined behaviour because
#      20 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 21 fx = fun(np.copy(x), *args)
#      22 # Make sure the function returns a true scalar
#      23 if not np.isscalar(fx):
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/scipy/optimize/_optimize.py:80, in MemoizeJac.__call__(self, x, *args)
#      78 def __call__(self, x, *args):
#      79     """ returns the function value """
# ---> 80     self._compute_if_needed(x, *args)
#      81     return self._value
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/scipy/optimize/_optimize.py:74, in MemoizeJac._compute_if_needed(self, x, *args)
#      72 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      73     self.x = np.asarray(x).copy()
# ---> 74     fg = self.fun(x, *args)
#      75     self.jac = fg[1]
#      76     self._value = fg[0]
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/generation/gen.py:197, in gen_candidates_scipy.<locals>.f_np_wrapper(x, f)
#     189 X = (
#     190     torch.from_numpy(x)
#     191     .to(initial_conditions)
#    (...)    194     .requires_grad_(True)
#     195 )
#     196 X_fix = fix_features(X, fixed_features=fixed_features)
# --> 197 loss = f(X_fix).sum()
#     198 # compute gradient w.r.t. the inputs (does not accumulate in leaves)
#     199 gradf = _arrayify(torch.autograd.grad(loss, X)[0].contiguous().view(-1))
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/generation/gen.py:238, in gen_candidates_scipy.<locals>.f(x)
#     237 def f(x):
# --> 238     return -acquisition_function(x)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/utils/transforms.py:298, in t_batch_mode_transform.<locals>.decorator.<locals>.decorated(acqf, X, *args, **kwargs)
#     296 # add t-batch dim
#     297 X = X if X.dim() > 2 else X.unsqueeze(0)
# --> 298 output = method(acqf, X, *args, **kwargs)
#     299 if hasattr(acqf, "model") and is_ensemble(acqf.model):
#     300     # IDEA: this could be wrapped into SampleReducingMCAcquisitionFunction
#     301     output = (
#     302         output.mean(dim=-1) if not acqf._log else logmeanexp(output, dim=-1)
#     303     )
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/acquisition/knowledge_gradient.py:188, in qKnowledgeGradient.forward(self, X)
#     183     X_actual = torch.cat(
#     184         [X_actual, match_batch_shape(self.X_pending, X_actual)], dim=-2
#     185     )
#     187 # construct the fantasy model of shape `num_fantasies x b`
# --> 188 fantasy_model = self.model.fantasize(
#     189     X=X_actual,
#     190     sampler=self.sampler,
#     191 )
#     193 # get the value function
#     194 value_function = _get_value_function(
#     195     model=fantasy_model,
#     196     objective=self.objective,
#     197     posterior_transform=self.posterior_transform,
#     198     sampler=self.inner_sampler,
#     199 )
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/models/model.py:398, in FantasizeMixin.fantasize(self, X, sampler, observation_noise, **kwargs)
#     396 if observation_noise is not None:
#     397     kwargs["noise"] = observation_noise.expand(Y_fantasized.shape[1:])
# --> 398 return self.condition_on_observations(
#     399     X=self.transform_inputs(X), Y=Y_fantasized, **kwargs
#     400 )
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/models/gpytorch.py:533, in BatchedMultiOutputGPyTorchModel.condition_on_observations(self, X, Y, **kwargs)
#     531 if noise is not None:
#     532     kwargs.update({"noise": noise})
# --> 533 fantasy_model = super().condition_on_observations(X=inputs, Y=targets, **kwargs)
#     534 fantasy_model._input_batch_shape = fantasy_model.train_targets.shape[
#     535     : (-1 if self._num_outputs == 1 else -2)
#     536 ]
#     537 if not self._is_fully_bayesian:
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/models/gpytorch.py:260, in GPyTorchModel.condition_on_observations(self, X, Y, noise, **kwargs)
#     256         kwargs.update({"noise": Yvar.squeeze(-1)})
#     257 # get_fantasy_model will properly copy any existing outcome transforms
#     258 # (since it deepcopies the original model)
# --> 260 return self.get_fantasy_model(inputs=X, targets=Y, **kwargs)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/gpytorch/models/exact_gp.py:251, in ExactGP.get_fantasy_model(self, inputs, targets, **kwargs)
#     248 self.likelihood = old_likelihood
#     250 new_model.likelihood = old_likelihood.get_fantasy_likelihood(**fantasy_kwargs)
# --> 251 new_model.prediction_strategy = old_pred_strat.get_fantasy_strategy(
#     252     inputs, targets, full_inputs, full_targets, full_output, **fantasy_kwargs
#     253 )
#     255 # if the fantasies are at the same points, we need to expand the inputs for the new model
#     256 if tbdim == ibdim + 1:
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/gpytorch/models/exact_prediction_strategies.py:167, in DefaultPredictionStrategy.get_fantasy_strategy(self, inputs, targets, full_inputs, full_targets, full_output, **kwargs)
#     164 mvn_obs = fant_likelihood(mvn, inputs, **kwargs)
#     166 fant_fant_covar = mvn_obs.covariance_matrix
# --> 167 fant_train_covar = to_dense(full_covar[..., num_train:, :num_train])
#     169 self.fantasy_inputs = inputs
#     170 self.fantasy_targets = targets
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/linear_operator/operators/_linear_operator.py:2993, in to_dense(obj)
#    2991     return obj
#    2992 elif isinstance(obj, LinearOperator):
# -> 2993     return obj.to_dense()
#    2994 else:
#    2995     raise TypeError("object of class {} cannot be made into a Tensor".format(obj.__class__.__name__))
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/gpytorch/utils/memoize.py:59, in _cached.<locals>.g(self, *args, **kwargs)
#      57 kwargs_pkl = pickle.dumps(kwargs)
#      58 if not _is_in_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl):
# ---> 59     return _add_to_cache(self, cache_name, method(self, *args, **kwargs), *args, kwargs_pkl=kwargs_pkl)
#      60 return _get_from_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/gpytorch/lazy/lazy_evaluated_kernel_tensor.py:410, in LazyEvaluatedKernelTensor.to_dense(self)
#     408 @cached
#     409 def to_dense(self):
# --> 410     return self.evaluate_kernel().to_dense()
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/gpytorch/utils/memoize.py:59, in _cached.<locals>.g(self, *args, **kwargs)
#      57 kwargs_pkl = pickle.dumps(kwargs)
#      58 if not _is_in_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl):
# ---> 59     return _add_to_cache(self, cache_name, method(self, *args, **kwargs), *args, kwargs_pkl=kwargs_pkl)
#      60 return _get_from_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/gpytorch/lazy/lazy_evaluated_kernel_tensor.py:25, in recall_grad_state.<locals>.wrapped(self, *args, **kwargs)
#      22 @functools.wraps(method)
#      23 def wrapped(self, *args, **kwargs):
#      24     with torch.set_grad_enabled(self._is_grad_enabled):
# ---> 25         output = method(self, *args, **kwargs)
#      26     return output
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/gpytorch/lazy/lazy_evaluated_kernel_tensor.py:362, in LazyEvaluatedKernelTensor.evaluate_kernel(self)
#     354     self.kernel.active_dims = None
#     355     res = self.kernel(
#     356         x1,
#     357         x2,
#    (...)    360         **self.params,
#     361     )
# --> 362     self.kernel.active_dims = temp_active_dims
#     364 # Check the size of the output
#     365 if settings.debug.on():
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/torch/nn/modules/module.py:2013, in Module.__setattr__(self, name, value)
#    2011     self.register_buffer(name, value, persistent)
#    2012 else:
# -> 2013     sign = inspect.signature(self.register_buffer)
#    2014     if "persistent" in sign.parameters:
#    2015         self.register_buffer(name, value, persistent)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/inspect.py:3345, in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3343 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3344     """Get a signature object for the passed callable."""
# -> 3345     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    3346                                    globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/inspect.py:3085, in Signature.from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    3081 @classmethod
#    3082 def from_callable(cls, obj, *,
#    3083                   follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3084     """Constructs Signature for the given callable object."""
# -> 3085     return _signature_from_callable(obj, sigcls=cls,
#    3086                                     follow_wrapper_chains=follow_wrapped,
#    3087                                     globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/inspect.py:2527, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2522     raise TypeError('{!r} is not a callable object'.format(obj))
#    2524 if isinstance(obj, types.MethodType):
#    2525     # In this case we skip the first parameter of the underlying
#    2526     # function (usually `self` or `cls`).
# -> 2527     sig = _get_signature_of(obj.__func__)
#    2529     if skip_bound_arg:
#    2530         return _signature_bound_method(sig)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/inspect.py:2597, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2592             return sig.replace(parameters=new_params)
#    2594 if isfunction(obj) or _signature_is_functionlike(obj):
#    2595     # If it's a pure Python function, or an object that is duck type
#    2596     # of a Python function (Cython functions, for instance), then:
# -> 2597     return _signature_from_function(sigcls, obj,
#    2598                                     skip_bound_arg=skip_bound_arg,
#    2599                                     globals=globals, locals=locals, eval_str=eval_str)
#    2601 if _signature_is_builtin(obj):
#    2602     return _signature_from_builtin(sigcls, obj,
#    2603                                    skip_bound_arg=skip_bound_arg)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/inspect.py:2441, in _signature_from_function(cls, func, skip_bound_arg, globals, locals, eval_str)
#    2439 for name in positional[:non_default_count]:
#    2440     kind = _POSITIONAL_ONLY if posonly_left else _POSITIONAL_OR_KEYWORD
# -> 2441     annotation = annotations.get(name, _empty)
#    2442     parameters.append(Parameter(name, annotation=annotation,
#    2443                                 kind=kind))
#    2444     if posonly_left:
#
# KeyboardInterrupt:
