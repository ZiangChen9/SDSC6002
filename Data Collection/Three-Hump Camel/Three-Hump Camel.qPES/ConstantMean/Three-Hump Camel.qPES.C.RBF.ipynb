# %% [markdown]
# # 0.Install

# %%
# !pip install torch gpytorch botorch

# %% [markdown]
# # 1.Import

# %%
import torch
import gpytorch
import botorch
import matplotlib.pyplot as plt
from botorch.test_functions.synthetic import ThreeHumpCamel,Hartmann
from numpy.ma.core import negative
from torch.quasirandom import SobolEngine
from botorch.sampling.normal import SobolQMCNormalSampler

from botorch.models import SingleTaskGP
from botorch.acquisition import qKnowledgeGradient, qLogNoisyExpectedImprovement
from botorch.acquisition.predictive_entropy_search import qPredictiveEntropySearch
from botorch.acquisition.utils import get_optimal_samples
from gpytorch.mlls import ExactMarginalLogLikelihood
from botorch.fit import fit_gpytorch_mll
from tqdm.notebook import tqdm
from botorch.models.transforms import Normalize, Standardize
from botorch.optim import optimize_acqf

from gpytorch.means import LinearMean
from gpytorch.kernels import ScaleKernel, RBFKernel
import warnings
import csv

# %% [markdown]
# # 2.Test Function: Valley-Shaped: ThreeHumpCamel

# %%
tkwargs = {
    "dtype": torch.float64,
}
d=2
bounds=torch.tensor([[-5.0, -5.0],[5.0,  5.0]],**tkwargs)
optimizer =torch.tensor([0.0, 0.0], **tkwargs)
optimal_value=0.0
test_f= ThreeHumpCamel(negate = True)
noise =0.5
def f4(x,noise):
  y=test_f(x)
  y=test_f(x)+noise*torch.randn_like(y)
  return y.unsqueeze(-1)
def f(x,noise):
  return f4(x,noise)

# %% [markdown]
# # 3.BayesOpt Loop: ThreeHumpCamel+qPredictiveEntropySearch+ConstantMean+RBFKernel

# %%
best_values=[]
result_reals=[]
runs=30
for i in tqdm(range(runs)):
  # Set SEED
  SEED=i
  torch.manual_seed(SEED)
  d=2

  # Initial xt and yt
  Init_num=10*d
  sobol= SobolEngine(dimension=d, scramble=True)
  xt = sobol.draw(Init_num).to(dtype=torch.float64)
  xt[:,0]=xt[:,0]*(bounds[1][0]-bounds[0][0])+bounds[0][0]
  xt[:,1]=xt[:,1]*(bounds[1][1]-bounds[0][1])+bounds[0][1]
  yt=f(xt,noise)
  yr=f(xt,0)

  # Records
  result_real=[val.item() for val in yr]
  result_noise=[val.item() for val in yt]
  best_value=[-max(result_real)]

  # Budget
  budget=40*d

  # Sampler
  sampler = SobolQMCNormalSampler(torch.Size([1024]))

  # Mean & Kernel
  mean_fn = gpytorch.means.ConstantMean()
  kernel_fn = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())

  # Loop
  for j in tqdm(range(budget)):
    # GP Model
    gp_1=SingleTaskGP(train_X=xt,
                      train_Y=yt,
                      input_transform=Normalize(d=d),
                      outcome_transform=Standardize(m=1),
                      mean_module=mean_fn,
                      covar_module=kernel_fn)
    # Fit
    fit_gpytorch_mll(ExactMarginalLogLikelihood(gp_1.likelihood, gp_1))

    # Acquisition Function
    num_samples = 12

    optimal_inputs, optimal_outputs = get_optimal_samples(model=gp_1, bounds=bounds,num_optima=num_samples)

    acf=qPredictiveEntropySearch(model=gp_1, optimal_inputs=optimal_inputs)

    # next train_X
    with warnings.catch_warnings():
      warnings.filterwarnings('ignore', category=RuntimeWarning)
      candidate, acq_value = optimize_acqf(acf, bounds=bounds, q=1, num_restarts=20, raw_samples=50,options={"dtype": torch.float64,"with_grad": False})

    # List of train_X
    xt= torch.cat([xt, candidate], dim=0)

    # next train_Y & next real_Y
    yr_next = f(candidate,0)
    yt_next = f(candidate,noise)

    # List of train_Y
    yt = torch.cat([yt, yt_next])

    # List of train_Y & List of real_Y
    result_noise.append(yt_next.squeeze(-1).item())
    result_real.append(yr_next.squeeze(-1).item())
    best_value.append(-max(result_real))
  # Update Records
  result_reals.append(result_real)
  best_values.append(best_value)

  # Plot
  iter_num=[k for k in range(0, budget+1)]
  min=[optimal_value for k in range(0, budget+1)]
  if i%3 == 0:
    plt.figure(figsize=(8, 6))
    plt.xlabel("Number of evaluations")
    plt.ylabel("Best value found")
    plt.title(f"Runs:{i+1}-{i+1+2}")
    plt.plot(iter_num,min,'--',label='Optimal Value')
  plt.plot(iter_num,best_value,label=f'Run:{i+1}')
  plt.legend(loc='upper right',)

  # Print
#   print(result_real)
# print(result_reals)
with open('result_reals_ThreeHumpCamel+qPredictiveEntropySearch+ConstantMean+RBF.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(best_values)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/80 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 56
#      54 with warnings.catch_warnings():
#      55   warnings.filterwarnings('ignore', category=RuntimeWarning)
# ---> 56   candidate, acq_value = optimize_acqf(acf, bounds=bounds, q=1, num_restarts=20, raw_samples=50,options={"dtype": torch.float64,"with_grad": False})
#      58 # List of train_X
#      59 xt= torch.cat([xt, candidate], dim=0)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/optim/optimize.py:631, in optimize_acqf(acq_function, bounds, q, num_restarts, raw_samples, options, inequality_constraints, equality_constraints, nonlinear_inequality_constraints, fixed_features, post_processing_func, batch_initial_conditions, return_best_only, gen_candidates, sequential, ic_generator, timeout_sec, return_full_tree, retry_on_optimization_warning, **ic_gen_kwargs)
#     608     gen_candidates = gen_candidates_scipy
#     609 opt_acqf_inputs = OptimizeAcqfInputs(
#     610     acq_function=acq_function,
#     611     bounds=bounds,
#    (...)    629     ic_gen_kwargs=ic_gen_kwargs,
#     630 )
# --> 631 return _optimize_acqf(opt_inputs=opt_acqf_inputs)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/optim/optimize.py:652, in _optimize_acqf(opt_inputs)
#     649     return _optimize_acqf_sequential_q(opt_inputs=opt_inputs)
#     651 # Batch optimization (including the case q=1)
# --> 652 return _optimize_acqf_batch(opt_inputs=opt_inputs)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/optim/optimize.py:408, in _optimize_acqf_batch(opt_inputs)
#     405         batch_acq_values = torch.cat(batch_acq_values_list).flatten()
#     406     return batch_candidates, batch_acq_values, opt_warnings
# --> 408 batch_candidates, batch_acq_values, ws = _optimize_batch_candidates()
#     410 optimization_warning_raised = any(
#     411     issubclass(w.category, OptimizationWarning) for w in ws
#     412 )
#     413 if optimization_warning_raised and opt_inputs.retry_on_optimization_warning:
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/optim/optimize.py:385, in _optimize_acqf_batch.<locals>._optimize_batch_candidates()
#     380 with warnings.catch_warnings(record=True) as ws:
#     381     warnings.simplefilter("always", category=OptimizationWarning)
#     382     (
#     383         batch_candidates_curr,
#     384         batch_acq_values_curr,
# --> 385     ) = opt_inputs.gen_candidates(
#     386         batched_ics_,
#     387         opt_inputs.acq_function,
#     388         lower_bounds=lower_bounds,
#     389         upper_bounds=upper_bounds,
#     390         options=gen_options,
#     391         fixed_features=opt_inputs.fixed_features,
#     392         timeout_sec=timeout_sec,
#     393         **gen_kwargs,
#     394     )
#     395 opt_warnings += ws
#     396 batch_candidates_list.append(batch_candidates_curr)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/generation/gen.py:240, in gen_candidates_scipy(initial_conditions, acquisition_function, lower_bounds, upper_bounds, inequality_constraints, equality_constraints, nonlinear_inequality_constraints, options, fixed_features, timeout_sec)
#     237 def f(x):
#     238     return -acquisition_function(x)
# --> 240 res = minimize_with_timeout(
#     241     fun=f_np_wrapper,
#     242     args=(f,),
#     243     x0=x0,
#     244     method=options.get("method", "SLSQP" if constraints else "L-BFGS-B"),
#     245     jac=with_grad,
#     246     bounds=bounds,
#     247     constraints=constraints,
#     248     callback=options.get("callback", None),
#     249     options={
#     250         k: v
#     251         for k, v in options.items()
#     252         if k not in ["method", "callback", "with_grad"]
#     253     },
#     254     timeout_sec=timeout_sec,
#     255 )
#     256 _process_scipy_result(res=res, options=options)
#     258 candidates = fix_features(
#     259     X=torch.from_numpy(res.x).to(initial_conditions).reshape(shapeX),
#     260     fixed_features=fixed_features,
#     261 )
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/optim/utils/timeout.py:86, in minimize_with_timeout(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options, timeout_sec)
#      83     # To prevent slowdowns after scipy 1.15.
#      84     # See https://github.com/scipy/scipy/issues/22438.
#      85     with threadpool_limits(limits=1, user_api="blas"):
# ---> 86         return optimize.minimize(
#      87             fun=fun,
#      88             x0=x0,
#      89             args=args,
#      90             method=method,
#      91             jac=jac,
#      92             hess=hess,
#      93             hessp=hessp,
#      94             bounds=bounds,
#      95             constraints=constraints,
#      96             tol=tol,
#      97             callback=wrapped_callback,
#      98             options=options,
#      99         )
#     100 except OptimizationTimeoutError as e:
#     101     msg = f"Optimization timed out after {e.runtime} seconds."
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/scipy/optimize/_minimize.py:738, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     735     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     736                              **options)
#     737 elif meth == 'l-bfgs-b':
# --> 738     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     739                            callback=callback, **options)
#     740 elif meth == 'tnc':
#     741     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     742                         **options)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/scipy/optimize/_lbfgsb_py.py:441, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     433 _lbfgsb.setulb(m, x, low_bnd, upper_bnd, nbd, f, g, factr, pgtol, wa,
#     434                iwa, task, lsave, isave, dsave, maxls, ln_task)
#     436 if task[0] == 3:
#     437     # The minimization routine wants f and g at the current x.
#     438     # Note that interruptions due to maxfun are postponed
#     439     # until the completion of the current minimization iteration.
#     440     # Overwrite f and g:
# --> 441     f, g = func_and_grad(x)
#     442 elif task[0] == 1:
#     443     # new iteration
#     444     n_iterations += 1
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:345, in ScalarFunction.fun_and_grad(self, x)
#     343     self._update_x(x)
#     344 self._update_fun()
# --> 345 self._update_grad()
#     346 return self.f, self.g
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:307, in ScalarFunction._update_grad(self)
#     305 if self._orig_grad in FD_METHODS:
#     306     self._update_fun()
# --> 307 self.g = self._wrapped_grad(self.x, f0=self.f)
#     308 self.g_updated = True
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:48, in _wrapper_grad.<locals>.wrapped1(x, f0)
#      46 def wrapped1(x, f0=None):
#      47     ncalls[0] += 1
# ---> 48     return approx_derivative(
#      49         fun, x, f0=f0, **finite_diff_options
#      50     )
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:523, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     520     use_one_sided = False
#     522 if sparsity is None:
# --> 523     return _dense_difference(fun_wrapped, x0, f0, h,
#     524                              use_one_sided, method)
#     525 else:
#     526     if not issparse(sparsity) and len(sparsity) == 2:
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:596, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     594     x1[i] += h[i]
#     595     dx = x1[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 596     df = fun(x1) - f0
#     597 elif method == '3-point' and use_one_sided[i]:
#     598     x1[i] += h[i]
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:474, in approx_derivative.<locals>.fun_wrapped(x)
#     471 if xp.isdtype(x.dtype, "real floating"):
#     472     x = xp.astype(x, x0.dtype)
# --> 474 f = np.atleast_1d(fun(x, *args, **kwargs))
#     475 if f.ndim > 1:
#     476     raise RuntimeError("`fun` return value has "
#     477                        "more than 1 dimension.")
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:21, in _wrapper_fun.<locals>.wrapped(x)
#      17 ncalls[0] += 1
#      18 # Send a copy because the user may overwrite it.
#      19 # Overwriting results in undefined behaviour because
#      20 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 21 fx = fun(np.copy(x), *args)
#      22 # Make sure the function returns a true scalar
#      23 if not np.isscalar(fx):
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/generation/gen.py:218, in gen_candidates_scipy.<locals>.f_np_wrapper(x, f)
#     216 with torch.no_grad():
#     217     X_fix = fix_features(X=X, fixed_features=fixed_features)
# --> 218     loss = f(X_fix).sum()
#     219 fval = loss.item()
#     220 return fval
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/generation/gen.py:238, in gen_candidates_scipy.<locals>.f(x)
#     237 def f(x):
# --> 238     return -acquisition_function(x)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/utils/transforms.py:344, in concatenate_pending_points.<locals>.decorated(cls, X, **kwargs)
#     342 if cls.X_pending is not None:
#     343     X = torch.cat([X, match_batch_shape(cls.X_pending, X)], dim=-2)
# --> 344 return method(cls, X, **kwargs)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/utils/transforms.py:298, in t_batch_mode_transform.<locals>.decorator.<locals>.decorated(acqf, X, *args, **kwargs)
#     296 # add t-batch dim
#     297 X = X if X.dim() > 2 else X.unsqueeze(0)
# --> 298 output = method(acqf, X, *args, **kwargs)
#     299 if hasattr(acqf, "model") and is_ensemble(acqf.model):
#     300     # IDEA: this could be wrapped into SampleReducingMCAcquisitionFunction
#     301     output = (
#     302         output.mean(dim=-1) if not acqf._log else logmeanexp(output, dim=-1)
#     303     )
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/acquisition/predictive_entropy_search.py:101, in qPredictiveEntropySearch.forward(self, X)
#      88 @concatenate_pending_points
#      89 @t_batch_mode_transform()
#      90 def forward(self, X: Tensor) -> Tensor:
#      91     r"""Evaluate qPredictiveEntropySearch on the candidate set `X`.
#      92
#      93     Args:
#    (...)     99         given design points `X`.
#     100     """
# --> 101     return self._compute_information_gain(X)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/acquisition/multi_objective/predictive_entropy_search.py:407, in qMultiObjectivePredictiveEntropySearch._compute_information_gain(self, X)
#     400 omega_f_nat_cov = torch.zeros(
#     401     batch_shape + torch.Size([num_pareto_samples, M, q + P, P, 2, 2]), **tkwargs
#     402 )
#     403 ###########################################################################
#     404 # RUN EP ONCE
#     405 ###########################################################################
#     406 # run update omega once
# --> 407 omega_f_nat_mean, omega_f_nat_cov = _safe_update_omega(
#     408     mean_f=pred_f_mean,
#     409     cov_f=pred_f_cov,
#     410     omega_f_nat_mean=omega_f_nat_mean,
#     411     omega_f_nat_cov=omega_f_nat_cov,
#     412     N=q,
#     413     P=P,
#     414     M=M,
#     415     maximize=self.maximize,
#     416     jitter=self.test_jitter,
#     417 )
#     418 ###########################################################################
#     419 # ADD THE CACHE FACTORS BACK
#     420 ###########################################################################
#     421 omega_f_nat_mean, omega_f_nat_cov = _augment_factors_with_cached_factors(
#     422     q=q,
#     423     N=N,
#    (...)    427     cached_omega_f_nat_cov=self._omega_f_nat_cov,
#     428 )
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/acquisition/multi_objective/predictive_entropy_search.py:877, in _safe_update_omega(mean_f, cov_f, omega_f_nat_mean, omega_f_nat_cov, N, P, M, maximize, jitter)
#     849 r"""Try to update the new omega factors by matching the moments. If the update
#     850 is not possible then this returns the initial omega factors.
#     851
#    (...)    874         the new omega natural covariance factors for the objective matrix.
#     875 """
#     876 try:
# --> 877     omega_f_nat_mean_new, omega_f_nat_cov_new = _update_omega(
#     878         mean_f=mean_f,
#     879         cov_f=cov_f,
#     880         omega_f_nat_mean=omega_f_nat_mean,
#     881         omega_f_nat_cov=omega_f_nat_cov,
#     882         N=N,
#     883         P=P,
#     884         M=M,
#     885         maximize=maximize,
#     886         jitter=jitter,
#     887     )
#     888     check_no_nans(omega_f_nat_mean_new)
#     889     check_no_nans(omega_f_nat_cov_new)
#
# File ~/miniconda3/envs/CHENYAO/lib/python3.12/site-packages/botorch/acquisition/multi_objective/predictive_entropy_search.py:733, in _update_omega(mean_f, cov_f, omega_f_nat_mean, omega_f_nat_cov, N, P, M, maximize, jitter)
#     731 cav_nat_cov_f = _replace_pareto_diagonal(cav_nat_cov_f)
#     732 identity = torch.diag_embed(torch.ones(cav_nat_cov_f.shape[:-1], **tkwargs))
# --> 733 cav_cov_f = torch.inverse(cav_nat_cov_f + jitter * identity)
#     735 cav_mean_f = torch.einsum("...ij,...j->...i", cav_cov_f, cav_nat_mean_f)
#     737 ###############################################################################
#     738 # COMPUTE THE NORMALIZATION CONSTANT
#     739 ###############################################################################
#     740 # `batch_shape x M x (N + P) x P`
#     741 # Equation 29
#
# KeyboardInterrupt:
